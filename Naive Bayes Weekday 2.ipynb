# %%
# Import packages
import os
import datetime
from datetime import date

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %matplotlib inline
sns.set()  # Setting seaborn as default style even if use only matplotlib

# constants
audio_features_col_names = [
    "Danceability",
    "Energy",
    "Loudness",
    "Speechiness",
    "Acousticness",
    "Instrumentalness",
    "Valence",
]

# reading data
spotify_filepath = os.path.join(os.getcwd(), "spotify", "spotify.csv")
print(spotify_filepath)

# creating dataframe
spotify_data = pd.read_csv(spotify_filepath, delimiter=";")

spotify_data.drop(["Song URL"], axis=1, inplace=True, errors="ignore")  # drop url
# spotify_data.info()

# make "Date" column datetime type
spotify_data["Date"] = pd.to_datetime(spotify_data["Date"], dayfirst=True)
spotify_data.loc[0]["Date"]

# reverse dates
spotify_data = spotify_data.sort_values(by="Date")
# spotify_data.head()
# ranks are also reversed now...

# Scale the audio features.
spotify_data["Loudness"] = spotify_data["Loudness"].apply(lambda x: np.log10(np.abs(x)) / 60)
spotify_data
# Out:
# /home/jovyan/spotify/spotify.csv
#         Rank                             Title  \
# 651935   200                   Ni**as In Paris
# 651770    62                            Sexual
# 651769    61      How Far I'll Go - From "Moa"
# 651768    60                          Too Good
# 651767    60                          Too Good
# ...      ...                               ...
# 198      135  Can't Hold Us (feat. Ray Dalton)
# 199      136                      Cartão Black
# 200      136                      Cartão Black
# 202      137                        Apocalypse
# 0          1                   Ella Baila Sola
#
#                                                   Artists       Date  \
# 651935                                  JAY-Z, Kanye West 2017-01-01
# 651770                                        NEIKED, Dyo 2017-01-01
# 651769                                       Alessia Cara 2017-01-01
# 651768                                     Drake, Rihanna 2017-01-01
# 651767                                     Drake, Rihanna 2017-01-01
# ...                                                   ...        ...
# 198     Macklemore & Ryan Lewis, Macklemore, Ryan Lewi... 2023-05-29
# 199                     MC Caverinha, KayBlack, Wall Hein 2023-05-29
# 200                     MC Caverinha, KayBlack, Wall Hein 2023-05-29
# 202                                  Cigarettes After Sex 2023-05-29
# 0                              Eslabon Armado, Peso Pluma 2023-05-29
#
#         Danceability  Energy  Loudness  Speechiness  Acousticness  \
# 651935         0.757   0.882  0.063118        0.248         0.076
# 651770         0.803   0.569  0.064479        0.074         0.062
# 651769         0.314   0.555  0.066372        0.370         0.157
# 651768         0.804   0.648  0.064873        0.117         0.057
# 651767         0.804   0.648  0.064873        0.117         0.057
# ...              ...     ...       ...          ...           ...
# 198            0.633   0.927  0.060835        0.084         0.027
# 199            0.842   0.468  0.065551        0.637         0.255
# 200            0.842   0.468  0.065551        0.637         0.255
# 202            0.369   0.467  0.065919        0.027         0.019
# 0              0.668   0.758  0.061900        0.033         0.483
#
#         Instrumentalness  Valence # of Artist         Artist (Ind.)  \
# 651935              0.00    0.684    Artist 2            Kanye West
# 651770              0.00    0.809    Artist 1                NEIKED
# 651769              0.00    0.159    Artist 1          Alessia Cara
# 651768              0.00    0.392    Artist 2               Rihanna
# 651767              0.00    0.392    Artist 1                 Drake
# ...                  ...      ...         ...                   ...
# 198                 0.00    0.880    Artist 4            Ray Dalton
# 199                 0.00    0.547    Artist 1          MC Caverinha
# 200                 0.00    0.547    Artist 2              KayBlack
# 202                 0.46    0.174    Artist 1  Cigarettes After Sex
# 0                   0.00    0.834    Artist 1        Eslabon Armado
#
#        # of Nationality    Nationality      Continent  Points (Total)  \
# 651935    Nationality 2  United States  Anglo-America               1
# 651770    Nationality 1         Sweden         Europe             139
# 651769    Nationality 1         Canada  Anglo-America             140
# 651768    Nationality 2       Barbados  Anglo-America             141
# 651767    Nationality 1         Canada  Anglo-America             141
# ...                 ...            ...            ...             ...
# 198       Nationality 4  United States  Anglo-America              66
# 199       Nationality 1         Brazil  Latin-America              65
# 200       Nationality 2         Brazil  Latin-America              65
# 202       Nationality 1  United States  Anglo-America              64
# 0         Nationality 1         Mexico  Latin-America             200
#
#         Points (Ind for each Artist/Nat)                      id
# 651935                          1.000000  2KpCpk6HjXXLb7nnXoXA5O
# 651770                         70.000000  3AsAuGTaDQzavZZThyYlop
# 651769                        140.000000  5hYTyyh2odQKphUbMqc5gN
# 651768                         70.000000  11KJSRSgaDxqydKYiD2Jew
# 651767                         70.000000  11KJSRSgaDxqydKYiD2Jew
# ...                                  ...                     ...
# 198                            16.500000  22skzmqfdWrjJylampe0kt
# 199                            21.666667  12YCtLHGk6tP6RbHDHflCs
# 200                            21.666667  12YCtLHGk6tP6RbHDHflCs
# 202                            64.000000  3AVrVz5rK8Hrqo9YGiVGN5
# 0                             100.000000  3qQbCzHBycnDpGskqOWY0E
#
# [651936 rows x 19 columns]

# %%
# First make copy and drop irrelevant features
spotify_data_copy = spotify_data.copy(deep=True)
spotify_data_copy.drop(["Artists", '# of Artist', 'Artist (Ind.)', '# of Nationality', 'Continent',
                        'Points (Ind for each Artist/Nat)', 'Rank'], axis=1, inplace=True)

# group by song title and take average vlues
data_by_song_mean = spotify_data_copy.groupby("Title").mean(numeric_only=True)
data_by_song_mean
# Out:
#                      Danceability  Energy  Loudness  Speechiness  \
# Title
#  '98 Braves                 0.488   0.670  0.062672        0.027
# !                           0.725   0.543  0.063335        0.084
# #PROUDCATOWNERREMIX         0.783   0.522  0.063240        0.390
# $$$                         0.774   0.507  0.064035        0.065
# $€ Freestyle                0.813   0.670  0.065626        0.335
# ...                           ...     ...       ...          ...
# Î©. VIVRE UN PEU            0.416   0.528  0.066914        0.291
# ÎŸ. OG                      0.576   0.446  0.066741        0.044
# İmdat                       0.786   0.748  0.064650        0.162
# アイドル                        0.574   0.935  0.057409        0.093
# 美女と野獣                       0.512   0.532  0.063897        0.027
#
#                      Acousticness  Instrumentalness  Valence  Points (Total)
# Title
#  '98 Braves                 0.097               0.0    0.484       71.750000
# !                           0.030               0.0    0.693       97.000000
# #PROUDCATOWNERREMIX         0.029               0.0    0.235       12.000000
# $$$                         0.064               0.0    0.508       84.833333
# $€ Freestyle                0.200               0.0    0.380      125.000000
# ...                           ...               ...      ...             ...
# Î©. VIVRE UN PEU            0.178               0.0    0.203       35.000000
# ÎŸ. OG                      0.773               0.4    0.060      117.000000
# İmdat                       0.267               0.0    0.562       72.562500
# アイドル                        0.112               0.0    0.836       90.522727
# 美女と野獣                       0.126               0.0    0.283       49.500000
#
# [7457 rows x 8 columns]

# %%
# create new dataframe with just data from 2022
data_copy_2022 = spotify_data.copy(deep=True)
data_copy_2022.sort_values("Date", ascending=True)
data_copy_2022 = data_copy_2022.loc[(data_copy_2022["Date"] > pd.to_datetime('2021-12-31')) # delete all dates excluding 2022
& (data_copy_2022["Date"] < pd.to_datetime('2023-1-1'))]

# dataset with one song per row and averaged feature values
songs_2022 = data_copy_2022.groupby("Title").mean(numeric_only=True)
songs_2022.drop(['Points (Total)', 'Rank', 'Points (Ind for each Artist/Nat)'], axis=1, inplace=True)
#songs_2022

# dataset with one song per day per row and total points
points_per_day = data_copy_2022.drop(audio_features_col_names + ['Artists', '# of Artist', 'Artist (Ind.)', 'Nationality', '# of Nationality', 'Continent', 'Points (Ind for each Artist/Nat)', 'id', 'Rank'], axis=1)

# split dataframe by date
points_by_date = {date: data for date, data in points_per_day.groupby('Date')}
# Now, points_by_date is a dictionary where the keys are dates and the values are the DataFrames for each date.
# Modify each date DataFrame to ensure no duplicate songs and random points for each song
for date, data in points_by_date.items():
    # Group by Song Title and select one random row for each song
    points_by_date[date] = data.groupby('Title', as_index=False).sample(n=1)
    
    # Reset the index of each grouped DataFrame
    points_by_date[date].reset_index(drop=True, inplace=True)
# To access the DataFrame for a specific date (for example, "2022-01-01"):
points_1 = points_by_date[pd.to_datetime('2022-01-01')]

# Now, we want to create a new DataFrame where:
# - Each row corresponds to a Song Title,
# - Each column corresponds to a Date,
# - Each entry represents the "Points" for that song on that date.

# We first concatenate all the DataFrames by date into a single DataFrame
points_concatenated = pd.concat(points_by_date.values(), ignore_index=True)

# Now we pivot the DataFrame to the required format
points_per_date_and_title = points_concatenated.pivot(index='Title', columns='Date', values='Points (Total)')
# convert NaN values to 0
points_per_date_and_title = points_per_date_and_title.fillna(0)
# add a total points accumulated column
#points_per_date_and_title['Total Points'] = points_per_date_and_title.sum(axis=1)
points_per_date_and_title
# Out:
# Date                                                2022-01-01  2022-01-02  \
# Title
# 'Till I Collapse                                           0.0         0.0
# (There's No Place Like) Home for the Holidays -...         0.0         0.0
# 0,440972222                                                0.0         0.0
# 1, 2, 3 (feat. Jason Derulo & De La Ghetto)                0.0         0.0
# 10 Things I Hate About You                                 0.0         0.0
# ...                                                        ...         ...
# we fell in love in october                                 0.0         0.0
# what would you do?                                         0.0         0.0
# you & me                                                   0.0         0.0
# you broke me first                                         0.0        46.0
# İmdat                                                      0.0         0.0
#
# Date                                                2022-01-03  2022-01-04  \
# Title
# 'Till I Collapse                                           7.0        31.0
# (There's No Place Like) Home for the Holidays -...         0.0         0.0
# 0,440972222                                                0.0         0.0
# 1, 2, 3 (feat. Jason Derulo & De La Ghetto)                0.0         0.0
# 10 Things I Hate About You                                 0.0         0.0
# ...                                                        ...         ...
# we fell in love in october                                 0.0         0.0
# what would you do?                                         0.0         0.0
# you & me                                                   0.0         0.0
# you broke me first                                        56.0        57.0
# İmdat                                                      0.0         0.0
#
# Date                                                2022-01-05  2022-01-06  \
# Title
# 'Till I Collapse                                          29.0        17.0
# (There's No Place Like) Home for the Holidays -...         0.0         0.0
# 0,440972222                                                0.0         0.0
# 1, 2, 3 (feat. Jason Derulo & De La Ghetto)                0.0         0.0
# 10 Things I Hate About You                                 0.0         0.0
# ...                                                        ...         ...
# we fell in love in october                                 0.0         0.0
# what would you do?                                         0.0         0.0
# you & me                                                   0.0         0.0
# you broke me first                                        54.0        54.0
# İmdat                                                      0.0         0.0
#
# Date                                                2022-01-07  2022-01-08  \
# Title
# 'Till I Collapse                                           0.0         0.0
# (There's No Place Like) Home for the Holidays -...         0.0         0.0
# 0,440972222                                                0.0         0.0
# 1, 2, 3 (feat. Jason Derulo & De La Ghetto)                0.0         0.0
# 10 Things I Hate About You                                 0.0         0.0
# ...                                                        ...         ...
# we fell in love in october                                 0.0         0.0
# what would you do?                                         0.0         0.0
# you & me                                                  89.0         0.0
# you broke me first                                        10.0         0.0
# İmdat                                                      0.0         0.0
#
# Date                                                2022-01-09  2022-01-10  \
# Title
# 'Till I Collapse                                           0.0        11.0
# (There's No Place Like) Home for the Holidays -...         0.0         0.0
# 0,440972222                                                0.0         0.0
# 1, 2, 3 (feat. Jason Derulo & De La Ghetto)                0.0         0.0
# 10 Things I Hate About You                                 0.0         0.0
# ...                                                        ...         ...
# we fell in love in october                                 0.0         0.0
# what would you do?                                         0.0         0.0
# you & me                                                   0.0         0.0
# you broke me first                                        28.0        44.0
# İmdat                                                      0.0         0.0
#
# Date                                                ...  2022-12-22  \
# Title                                               ...
# 'Till I Collapse                                    ...         0.0
# (There's No Place Like) Home for the Holidays -...  ...         0.0
# 0,440972222                                         ...         0.0
# 1, 2, 3 (feat. Jason Derulo & De La Ghetto)         ...         0.0
# 10 Things I Hate About You                          ...         0.0
# ...                                                 ...         ...
# we fell in love in october                          ...         0.0
# what would you do?                                  ...         0.0
# you & me                                            ...         0.0
# you broke me first                                  ...         0.0
# İmdat                                               ...         0.0
#
# Date                                                2022-12-23  2022-12-24  \
# Title
# 'Till I Collapse                                           0.0         0.0
# (There's No Place Like) Home for the Holidays -...         0.0        57.0
# 0,440972222                                                0.0         0.0
# 1, 2, 3 (feat. Jason Derulo & De La Ghetto)                0.0         0.0
# 10 Things I Hate About You                                 0.0         0.0
# ...                                                        ...         ...
# we fell in love in october                                 0.0         0.0
# what would you do?                                         0.0         0.0
# you & me                                                   0.0         0.0
# you broke me first                                         0.0         0.0
# İmdat                                                      0.0         0.0
#
# Date                                                2022-12-25  2022-12-26  \
# Title
# 'Till I Collapse                                           0.0         0.0
# (There's No Place Like) Home for the Holidays -...       100.0         0.0
# 0,440972222                                                0.0         0.0
# 1, 2, 3 (feat. Jason Derulo & De La Ghetto)                0.0         0.0
# 10 Things I Hate About You                                 0.0         0.0
# ...                                                        ...         ...
# we fell in love in october                                 0.0         0.0
# what would you do?                                         0.0         0.0
# you & me                                                   0.0         0.0
# you broke me first                                         0.0         0.0
# İmdat                                                      0.0         0.0
#
# Date                                                2022-12-27  2022-12-28  \
# Title
# 'Till I Collapse                                           0.0         0.0
# (There's No Place Like) Home for the Holidays -...         0.0         0.0
# 0,440972222                                                0.0         0.0
# 1, 2, 3 (feat. Jason Derulo & De La Ghetto)                0.0         0.0
# 10 Things I Hate About You                                 0.0         0.0
# ...                                                        ...         ...
# we fell in love in october                                 0.0         0.0
# what would you do?                                         0.0         0.0
# you & me                                                   0.0         0.0
# you broke me first                                         0.0         0.0
# İmdat                                                      0.0         0.0
#
# Date                                                2022-12-29  2022-12-30  \
# Title
# 'Till I Collapse                                           0.0         0.0
# (There's No Place Like) Home for the Holidays -...         0.0         0.0
# 0,440972222                                                0.0         0.0
# 1, 2, 3 (feat. Jason Derulo & De La Ghetto)                0.0         0.0
# 10 Things I Hate About You                                 0.0         0.0
# ...                                                        ...         ...
# we fell in love in october                                 0.0         0.0
# what would you do?                                         0.0         0.0
# you & me                                                   0.0         0.0
# you broke me first                                         0.0         0.0
# İmdat                                                      0.0         0.0
#
# Date                                                2022-12-31
# Title
# 'Till I Collapse                                           0.0
# (There's No Place Like) Home for the Holidays -...         0.0
# 0,440972222                                                0.0
# 1, 2, 3 (feat. Jason Derulo & De La Ghetto)                0.0
# 10 Things I Hate About You                                 0.0
# ...                                                        ...
# we fell in love in october                                 0.0
# what would you do?                                         0.0
# you & me                                                   0.0
# you broke me first                                         0.0
# İmdat                                                      0.0
#
# [1433 rows x 365 columns]

# %%
# now create a dataframe where the rows are songs and columns are weekday and weekend

# Convert columns to datetime (if not already)
points_per_date_and_title.columns = pd.to_datetime(points_per_date_and_title.columns)

# Create two masks: one for weekdays (Monday to Friday), and one for weekends (Saturday and Sunday)
weekdays_mask = points_per_date_and_title.columns.weekday < 5  # Monday (0) to Friday (4)
weekends_mask = ~weekdays_mask  # Saturday (5) and Sunday (6)

# Calculate average points for weekdays (Monday to Friday)
weekday_avg = points_per_date_and_title.loc[:, weekdays_mask].mean(axis=1)

# Calculate average points for weekends (Saturday and Sunday)
weekend_avg = points_per_date_and_title.loc[:, weekends_mask].mean(axis=1)

# Create a new DataFrame with song titles as rows and "weekday" and "weekend" columns
weekday_weekend = pd.DataFrame({
    'Title': points_per_date_and_title.index,
    'Weekday': weekday_avg,
    'Weekend': weekend_avg
})

weekday_weekend
# Out:
#                                                                                                 Title  \
# Title
# 'Till I Collapse                                                                     'Till I Collapse
# (There's No Place Like) Home for the Holidays -...  (There's No Place Like) Home for the Holidays ...
# 0,440972222                                                                               0,440972222
# 1, 2, 3 (feat. Jason Derulo & De La Ghetto)               1, 2, 3 (feat. Jason Derulo & De La Ghetto)
# 10 Things I Hate About You                                                 10 Things I Hate About You
# ...                                                                                               ...
# we fell in love in october                                                 we fell in love in october
# what would you do?                                                                 what would you do?
# you & me                                                                                     you & me
# you broke me first                                                                 you broke me first
# İmdat                                                                                           İmdat
#
#                                                       Weekday    Weekend
# Title
# 'Till I Collapse                                    28.119231  10.095238
# (There's No Place Like) Home for the Holidays -...   0.000000   1.495238
# 0,440972222                                          2.488462   0.790476
# 1, 2, 3 (feat. Jason Derulo & De La Ghetto)          0.438462   0.314286
# 10 Things I Hate About You                           6.869231   4.142857
# ...                                                       ...        ...
# we fell in love in october                           7.038462   8.352381
# what would you do?                                   0.311538   0.000000
# you & me                                             0.342308   0.000000
# you broke me first                                   5.738462   2.361905
# İmdat                                                3.138462   3.285714
#
# [1433 rows x 3 columns]

# %%
# Create a new DataFrame where rows are song titles and the entries are binary
binary = (weekday_weekend['Weekday'] > weekday_weekend['Weekend']).astype(int)

# Create a final DataFrame where we use the song titles as the index
weekday_binary = pd.DataFrame(binary, columns=['Weekday > Weekend'])
weekday_binary.index = weekday_weekend['Title']
weekday_binary
# Out:
#                                                     Weekday > Weekend
# Title
# 'Till I Collapse                                                    1
# (There's No Place Like) Home for the Holidays -...                  0
# 0,440972222                                                         1
# 1, 2, 3 (feat. Jason Derulo & De La Ghetto)                         1
# 10 Things I Hate About You                                          1
# ...                                                               ...
# we fell in love in october                                          0
# what would you do?                                                  1
# you & me                                                            1
# you broke me first                                                  1
# İmdat                                                               0
#
# [1433 rows x 1 columns]

# %%
data_by_song_mean
# Out:
#                      Danceability  Energy  Loudness  Speechiness  \
# Title
#  '98 Braves                 0.488   0.670  0.062672        0.027
# !                           0.725   0.543  0.063335        0.084
# #PROUDCATOWNERREMIX         0.783   0.522  0.063240        0.390
# $$$                         0.774   0.507  0.064035        0.065
# $€ Freestyle                0.813   0.670  0.065626        0.335
# ...                           ...     ...       ...          ...
# Î©. VIVRE UN PEU            0.416   0.528  0.066914        0.291
# ÎŸ. OG                      0.576   0.446  0.066741        0.044
# İmdat                       0.786   0.748  0.064650        0.162
# アイドル                        0.574   0.935  0.057409        0.093
# 美女と野獣                       0.512   0.532  0.063897        0.027
#
#                      Acousticness  Instrumentalness  Valence  Points (Total)
# Title
#  '98 Braves                 0.097               0.0    0.484       71.750000
# !                           0.030               0.0    0.693       97.000000
# #PROUDCATOWNERREMIX         0.029               0.0    0.235       12.000000
# $$$                         0.064               0.0    0.508       84.833333
# $€ Freestyle                0.200               0.0    0.380      125.000000
# ...                           ...               ...      ...             ...
# Î©. VIVRE UN PEU            0.178               0.0    0.203       35.000000
# ÎŸ. OG                      0.773               0.4    0.060      117.000000
# İmdat                       0.267               0.0    0.562       72.562500
# アイドル                        0.112               0.0    0.836       90.522727
# 美女と野獣                       0.126               0.0    0.283       49.500000
#
# [7457 rows x 8 columns]

# %%
# Merge the two DataFrames on the song title (index)
songs_features_weekday = data_by_song_mean.join(weekday_binary, how='inner')
songs_features_weekday = songs_features_weekday.drop('Points (Total)', axis=1)
songs_features_weekday
# Out:
#                                                     Danceability    Energy  \
# Title
# 'Till I Collapse                                        0.549341  0.848788
# (There's No Place Like) Home for the Holidays -...      0.478000  0.341000
# 0,440972222                                             0.696000  0.793000
# 1, 2, 3 (feat. Jason Derulo & De La Ghetto)             0.792000  0.895000
# 10 Things I Hate About You                              0.544000  0.786000
# ...                                                          ...       ...
# we fell in love in october                              0.566000  0.366000
# what would you do?                                      0.795000  0.620000
# you & me                                                0.744000  0.535000
# you broke me first                                      0.667000  0.373000
# İmdat                                                   0.786000  0.748000
#
#                                                     Loudness  Speechiness  \
# Title
# 'Till I Collapse                                    0.058542     0.190916
# (There's No Place Like) Home for the Holidays -...  0.068314     0.051000
# 0,440972222                                         0.062640     0.097000
# 1, 2, 3 (feat. Jason Derulo & De La Ghetto)         0.058217     0.059000
# 10 Things I Hate About You                          0.007879     0.050000
# ...                                                      ...          ...
# we fell in love in october                          0.068458     0.028000
# what would you do?                                  0.062849     0.066500
# you & me                                            0.066295     0.074000
# you broke me first                                  0.066210     0.050000
# İmdat                                               0.064650     0.162000
#
#                                                     Acousticness  \
# Title
# 'Till I Collapse                                         0.06781
# (There's No Place Like) Home for the Holidays -...       0.89700
# 0,440972222                                              0.06800
# 1, 2, 3 (feat. Jason Derulo & De La Ghetto)              0.16500
# 10 Things I Hate About You                               0.01000
# ...                                                          ...
# we fell in love in october                               0.11300
# what would you do?                                       0.29200
# you & me                                                 0.27900
# you broke me first                                       0.78500
# İmdat                                                    0.26700
#
#                                                     Instrumentalness  \
# Title
# 'Till I Collapse                                               0.000
# (There's No Place Like) Home for the Holidays -...             0.000
# 0,440972222                                                    0.000
# 1, 2, 3 (feat. Jason Derulo & De La Ghetto)                    0.000
# 10 Things I Hate About You                                     0.000
# ...                                                              ...
# we fell in love in october                                     0.181
# what would you do?                                             0.000
# you & me                                                       0.000
# you broke me first                                             0.000
# İmdat                                                          0.000
#
#                                                      Valence  \
# Title
# 'Till I Collapse                                    0.100000
# (There's No Place Like) Home for the Holidays -...  0.474000
# 0,440972222                                         0.698000
# 1, 2, 3 (feat. Jason Derulo & De La Ghetto)         0.793862
# 10 Things I Hate About You                          0.446000
# ...                                                      ...
# we fell in love in october                          0.237000
# what would you do?                                  0.711000
# you & me                                            0.106000
# you broke me first                                  0.082000
# İmdat                                               0.562000
#
#                                                     Weekday > Weekend
# Title
# 'Till I Collapse                                                    1
# (There's No Place Like) Home for the Holidays -...                  0
# 0,440972222                                                         1
# 1, 2, 3 (feat. Jason Derulo & De La Ghetto)                         1
# 10 Things I Hate About You                                          1
# ...                                                               ...
# we fell in love in october                                          0
# what would you do?                                                  1
# you & me                                                            1
# you broke me first                                                  1
# İmdat                                                               0
#
# [1433 rows x 8 columns]

# %%
# Problem: some values of loudness (3) are negative
# Filter rows with any negative values
negative_rows = songs_features_weekday[(songs_features_weekday < 0).any(axis=1)]

# Print the filtered rows
print(negative_rows)

# Solution: set them to 0
songs_features_weekday[songs_features_weekday < 0] = 0
# Out:
# Empty DataFrame
# Columns: [Danceability, Energy, Loudness, Speechiness, Acousticness, Instrumentalness, Valence, Weekday > Weekend]
# Index: []

# %%
# now try Naive Bayes on this dataset
X = songs_features_weekday.drop('Weekday > Weekend', axis=1)
y = songs_features_weekday['Weekday > Weekend']

# 'string {}'.format(x) prints the string + x in the {} position
print('Number of songs more popular on weekdays: {}'.format((y==1).sum())) #summing all entries of y which is equal to 1
print('Number of songs more popular on weekends: {}'.format((y==0).sum()))
# Out:
# Number of songs more popular on weekdays: 796
# Number of songs more popular on weekends: 637

# %%
gnb = GaussianNB()
gnb.fit(X=X, y=y)
# Out:
# GaussianNB()

# %%
tr_pred = gnb.predict(X=X)

ca = accuracy_score(y, gnb.predict(X)) # or ca = gnb.score(X,y)
print('Training set accuracy: {:.2f}%'.format(ca*100))
# Out:
# Training set accuracy: 58.83%
